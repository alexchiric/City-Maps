# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: city2graph in /Users/alexchiric/Documents/Projects/City Maps/.venv/lib/python3.14/site-packages (from -r requirements.txt (line 1)) (0.1.6)
# Requirement already satisfied: geopandas in /Users/alexchiric/Documents/Projects/City Maps/.venv/lib/python3.14/site-packages (from -r requirements.txt (line 2)) (1.1.3)
# Requirement already satisfied: pandas in /Users/alexchiric/Documents/Projects/City Maps/.venv/lib/python3.14/site-packages (from -r requirements.txt (line 3)) (3.0.3)
# Requirement already satisfied: osmnx in /Users/alexchiric/Documents/Projects/City Maps/.venv/lib/python3.14/site-packages (from -r requirements.txt (line 4)) (2.1.0)
# Requirement already satisfied: matplotlib in /Users/alexchiric/Documents/Projects/City Maps/.venv/lib/python3.14/site-packages (from -r requirements.txt (line 5)) (3.11.0)
# Requirement already satisfied: folium in /Users/alexchiric/Documents/Projects/City Maps/.venv/lib/python3.14/site-packages (from -r requirements.txt (line 6)) (0.20.0)
# Requirement already satisfied: h3 in /Users/alexchiric/Documents/Projects/City Maps/.venv/lib/python3.14/site-packages (from -r requirements.txt (line 7)) (4.5.0)
# Requirement already satisfied: mapclassify in /Users/alexchiric/Documents/Projects/City Maps/.venv/lib/python3.14/site-packages (from -r requirements.txt (line 8)) (2.10.0)
# Requirement already satisfied: shapely in /Users/alexchiric/Documents/Projects/City Maps/.venv/lib/python3.14/site-packages (from -r requirements.txt (line 9)) (2.1.2)
# Requirement already satisfied: libpysal>=4.12.1 in /Users/alexchiric/Documents/Projects/City Maps/.venv/lib/python3.14/site-packages (from city2graph->-r requirements.txt (line 1)) (4.14.1)
# Requirement already satisfied: momepy in /Users/alexchiric/Documents/Projects/City Maps/.venv/lib/python3.14/site-packages (from city2graph->-r requirements.txt (line 1)) (0.11.0)
# Requirement already satisfied: networkx>=2.8 in /Users/alexchiric/Documents/Projects/City Maps/.venv/lib/python3.14/site-packages (from city2graph->-r requirements.txt (line 1)) (3.6.1)
# Requirement already satisfied: overturemaps in /Users/alexchiric/Documents/Projects/City Maps/.venv/lib/python3.14/site-packages (from city2graph->-r requirements.txt (line 1)) (1.0.0)
# Requirement already satisfied: numpy>=1.24 in /Users/alexchiric/Documents/Projects/City Maps/.venv/lib/python3.14/site-packages (from geopandas->-r requirements.txt (line 2)) (2.5.0)
# Requirement already satisfied: pyogrio>=0.7.2 in /Users/alexchiric/Documents/Projects/City Maps/.venv/lib/python3.14/site-packages (from geopandas->-r requirements.txt (line 2)) (0.12.1)
# Requirement already satisfied: packaging in /Users/alexchiric/Documents/Projects/City Maps/.venv/lib/python3.14/site-packages (from geopandas->-r requirements.txt (line 2)) (26.2)
# Requirement already satisfied: pyproj>=3.5.0 in /Users/alexchiric/Documents/Projects/City Maps/.venv/lib/python3.14/site-packages (from geopandas->-r requirements.txt (line 2)) (3.7.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/alexchiric/Documents/Projects/City Maps/.venv/lib/python3.14/site-packages (from pandas->-r requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: requests>=2.30 in /Users/alexchiric/Documents/Projects/City Maps/.venv/lib/python3.14/site-packages (from osmnx->-r requirements.txt (line 4)) (2.34.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/alexchiric/Documents/Projects/City Maps/.venv/lib/python3.14/site-packages (from matplotlib->-r requirements.txt (line 5)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/alexchiric/Documents/Projects/City Maps/.venv/lib/python3.14/site-packages (from matplotlib->-r requirements.txt (line 5)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/alexchiric/Documents/Projects/City Maps/.venv/lib/python3.14/site-packages (from matplotlib->-r requirements.txt (line 5)) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/alexchiric/Documents/Projects/City Maps/.venv/lib/python3.14/site-packages (from matplotlib->-r requirements.txt (line 5)) (1.5.0)
# Requirement already satisfied: pillow>=9 in /Users/alexchiric/Documents/Projects/City Maps/.venv/lib/python3.14/site-packages (from matplotlib->-r requirements.txt (line 5)) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /Users/alexchiric/Documents/Projects/City Maps/.venv/lib/python3.14/site-packages (from matplotlib->-r requirements.txt (line 5)) (3.3.2)
# Requirement already satisfied: branca>=0.6.0 in /Users/alexchiric/Documents/Projects/City Maps/.venv/lib/python3.14/site-packages (from folium->-r requirements.txt (line 6)) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in /Users/alexchiric/Documents/Projects/City Maps/.venv/lib/python3.14/site-packages (from folium->-r requirements.txt (line 6)) (3.1.6)
# Requirement already satisfied: xyzservices in /Users/alexchiric/Documents/Projects/City Maps/.venv/lib/python3.14/site-packages (from folium->-r requirements.txt (line 6)) (2026.3.0)
# Requirement already satisfied: scikit-learn>=1.4 in /Users/alexchiric/Documents/Projects/City Maps/.venv/lib/python3.14/site-packages (from mapclassify->-r requirements.txt (line 8)) (1.9.0)
# Requirement already satisfied: scipy>=1.12 in /Users/alexchiric/Documents/Projects/City Maps/.venv/lib/python3.14/site-packages (from mapclassify->-r requirements.txt (line 8)) (1.18.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/alexchiric/Documents/Projects/City Maps/.venv/lib/python3.14/site-packages (from jinja2>=2.9->folium->-r requirements.txt (line 6)) (3.0.3)
# Requirement already satisfied: beautifulsoup4>=4.13.0 in /Users/alexchiric/Documents/Projects/City Maps/.venv/lib/python3.14/site-packages (from libpysal>=4.12.1->city2graph->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: platformdirs>=3.11.0 in /Users/alexchiric/Documents/Projects/City Maps/.venv/lib/python3.14/site-packages (from libpysal>=4.12.1->city2graph->-r requirements.txt (line 1)) (4.10.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /Users/alexchiric/Documents/Projects/City Maps/.venv/lib/python3.14/site-packages (from beautifulsoup4>=4.13.0->libpysal>=4.12.1->city2graph->-r requirements.txt (line 1)) (2.8.4)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/alexchiric/Documents/Projects/City Maps/.venv/lib/python3.14/site-packages (from beautifulsoup4>=4.13.0->libpysal>=4.12.1->city2graph->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: certifi in /Users/alexchiric/Documents/Projects/City Maps/.venv/lib/python3.14/site-packages (from pyogrio>=0.7.2->geopandas->-r requirements.txt (line 2)) (2026.6.17)
# Requirement already satisfied: six>=1.5 in /Users/alexchiric/Documents/Projects/City Maps/.venv/lib/python3.14/site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 3)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/alexchiric/Documents/Projects/City Maps/.venv/lib/python3.14/site-packages (from requests>=2.30->osmnx->-r requirements.txt (line 4)) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/alexchiric/Documents/Projects/City Maps/.venv/lib/python3.14/site-packages (from requests>=2.30->osmnx->-r requirements.txt (line 4)) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/alexchiric/Documents/Projects/City Maps/.venv/lib/python3.14/site-packages (from requests>=2.30->osmnx->-r requirements.txt (line 4)) (2.7.0)
# Requirement already satisfied: joblib>=1.4.0 in /Users/alexchiric/Documents/Projects/City Maps/.venv/lib/python3.14/site-packages (from scikit-learn>=1.4->mapclassify->-r requirements.txt (line 8)) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in /Users/alexchiric/Documents/Projects/City Maps/.venv/lib/python3.14/site-packages (from scikit-learn>=1.4->mapclassify->-r requirements.txt (line 8)) (2.22.1)
# Requirement already satisfied: threadpoolctl>=3.5.0 in /Users/alexchiric/Documents/Projects/City Maps/.venv/lib/python3.14/site-packages (from scikit-learn>=1.4->mapclassify->-r requirements.txt (line 8)) (3.6.0)
# Requirement already satisfied: tqdm>=4.65 in /Users/alexchiric/Documents/Projects/City Maps/.venv/lib/python3.14/site-packages (from momepy->city2graph->-r requirements.txt (line 1)) (4.68.3)
# Requirement already satisfied: click>=8.3.0 in /Users/alexchiric/Documents/Projects/City Maps/.venv/lib/python3.14/site-packages (from overturemaps->city2graph->-r requirements.txt (line 1)) (8.4.2)
# Requirement already satisfied: colorama>=0.4.6 in /Users/alexchiric/Documents/Projects/City Maps/.venv/lib/python3.14/site-packages (from overturemaps->city2graph->-r requirements.txt (line 1)) (0.4.6)
# Requirement already satisfied: orjson>=3.9.0 in /Users/alexchiric/Documents/Projects/City Maps/.venv/lib/python3.14/site-packages (from overturemaps->city2graph->-r requirements.txt (line 1)) (3.11.9)
# Requirement already satisfied: pyarrow>=15.0.2 in /Users/alexchiric/Documents/Projects/City Maps/.venv/lib/python3.14/site-packages (from overturemaps->city2graph->-r requirements.txt (line 1)) (24.0.0)
# Requirement already satisfied: pyfiglet>=1.0.2 in /Users/alexchiric/Documents/Projects/City Maps/.venv/lib/python3.14/site-packages (from overturemaps->city2graph->-r requirements.txt (line 1)) (1.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import osmnx as ox
import geopandas as gpd
import pandas as pd
import city2graph as c2g
from concurrent.futures import ThreadPoolExecutor, as_completed
import matplotlib.pyplot as plt
import h3
import folium
from shapely.geometry import Polygon

# %%
place = "Bucharest, Romania"

g = ox.geocode_to_gdf(place)
print(g.geom_type.iloc[0], "—", g.iloc[0]["display_name"])
print(g.drop(columns="geometry")) 

g.explore()
# Out:
# Polygon — Bucharest, Romania
#    bbox_west  bbox_south  bbox_east  bbox_north  place_id  osm_type  osm_id  \
# 0  25.966674   44.334247  26.225577   44.541396  61427700  relation  377733
#
#          lat        lon     class            type  place_rank  importance  \
# 0  44.436141  26.102684  boundary  administrative           8     0.76123
#
#   addresstype       name        display_name
# 0        city  Bucharest  Bucharest, Romania
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_813bcb80a05ac81353107419dfd609c7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_813bcb80a05ac81353107419dfd609c7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_813bcb80a05ac81353107419dfd609c7 = L.map(
#                 &quot;map_813bcb80a05ac81353107419dfd609c7&quot;,
#                 {
#                     center: [44.4378215, 26.096125649999998],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_813bcb80a05ac81353107419dfd609c7);
#
#
#
#
#
#             var tile_layer_82ac1a0e4078d43cc9b75b908d160f55 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_82ac1a0e4078d43cc9b75b908d160f55.addTo(map_813bcb80a05ac81353107419dfd609c7);
#
#
#             map_813bcb80a05ac81353107419dfd609c7.fitBounds(
#                 [[44.3342466, 25.9666745], [44.5413964, 26.2255768]],
#                 {}
#             );
#
#
#         function geo_json_8903a17dfe381bc2a281626bdcd687fc_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_8903a17dfe381bc2a281626bdcd687fc_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_8903a17dfe381bc2a281626bdcd687fc_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_8903a17dfe381bc2a281626bdcd687fc_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_8903a17dfe381bc2a281626bdcd687fc_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_8903a17dfe381bc2a281626bdcd687fc.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_8903a17dfe381bc2a281626bdcd687fc_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_8903a17dfe381bc2a281626bdcd687fc = L.geoJson(null, {
#                 onEachFeature: geo_json_8903a17dfe381bc2a281626bdcd687fc_onEachFeature,
#
#                 style: geo_json_8903a17dfe381bc2a281626bdcd687fc_styler,
#                 pointToLayer: geo_json_8903a17dfe381bc2a281626bdcd687fc_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_8903a17dfe381bc2a281626bdcd687fc_add (data) {
#             geo_json_8903a17dfe381bc2a281626bdcd687fc
#                 .addData(data);
#         }
#             geo_json_8903a17dfe381bc2a281626bdcd687fc_add({&quot;bbox&quot;: [25.9666745, 44.3342466, 26.2255768, 44.5413964], &quot;features&quot;: [{&quot;bbox&quot;: [25.9666745, 44.3342466, 26.2255768, 44.5413964], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[25.9666745, 44.4407414], [25.9668109, 44.4395493], [25.9670073, 44.4379933], [25.96722, 44.4364458], [25.9668214, 44.4364835], [25.9668322, 44.4361886], [25.9669321, 44.4356875], [25.9670155, 44.4351917], [25.9671139, 44.4343198], [25.9671514, 44.433988], [25.9671

# %%
tag_groups = {
    "education": {"amenity": ["school", "kindergarten", "university", "college", "library"]},
    "health":    {"amenity": ["hospital", "clinic", "pharmacy", "doctors"], "healthcare": True},
    "green":     {"leisure": ["park", "playground", "garden", "sports_centre", "fitness_centre"]},
    "groceries": {"shop": ["supermarket", "convenience", "bakery", "greengrocer"],
                  "amenity": ["marketplace"]},
    "transit":   {"railway": ["station", "subway_entrance", "tram_stop"], "highway": ["bus_stop"]},
    "culture":   {"amenity": ["cafe", "restaurant", "bar", "cinema", "theatre"],
                  "tourism": ["museum", "gallery"]},
    "services":  {"amenity": ["bank", "atm", "post_office"]}
}

area = ox.geocode_to_gdf(place).geometry.iloc[0]

def fetch(cat, tags):
    g = ox.features_from_polygon(area, tags=tags)
    g["poi_category"] = cat
    return g.to_crs(4326)

frames = []
with ThreadPoolExecutor(max_workers=3) as ex:                 
    futures = {ex.submit(fetch, c, t): c for c, t in tag_groups.items()}
    for fut in as_completed(futures):
        cat = futures[fut]
        try:
            frames.append(fut.result())
        except Exception as e:                                
            print(f"{cat} failed: {e}")                       

pois = gpd.GeoDataFrame(pd.concat(frames), crs=4326)

display(pois)
# Out:
#                                                             geometry  \
# element id
# node    218092022                           POINT (26.17836 44.4422)
#         271285333                          POINT (26.06146 44.42082)
#         444361321                          POINT (26.05532 44.48421)
#         494791040                          POINT (26.11326 44.43714)
#         501932616                          POINT (26.09828 44.42606)
# ...                                                              ...
# way     217416250  POLYGON ((26.09474 44.38702, 26.09511 44.38712...
#         219735025  POLYGON ((26.07845 44.49554, 26.07874 44.49554...
#         318990256  POLYGON ((26.11851 44.48117, 26.11866 44.48122...
#         405520011  POLYGON ((26.08318 44.45251, 26.08334 44.4524,...
#         948792755  POLYGON ((26.03568 44.43451, 26.03568 44.43448...
#
#                         amenity                           name  addr:city  \
# element id
# node    218092022  kindergarten               Grădinița nr. 23        NaN
#         271285333        school    Liceul Teoretic "Ion Barbu"  București
#         444361321        school                 School no. 178        NaN
#         494791040        school     Colegiul Economic "Hermes"  București
#         501932616  kindergarten            Grădinița Prikindel        NaN
# ...                         ...                            ...        ...
# way     217416250   post_office  Centrala Telefonică Giurgiu 1        NaN
#         219735025          bank             Banca Transilvania  București
#         318990256          bank                            BCR  București
#         405520011          bank                            BRD  București
#         948792755          bank                            BCR  București
#
#                   addr:housenumber                  addr:street grades  \
# element id
# node    218092022              NaN                          NaN    NaN
#         271285333               18             Strada Năbucului   0-12
#         444361321              NaN                          NaN    NaN
#         494791040              152                Calea Moșilor    NaN
#         501932616              NaN                          NaN    NaN
# ...                            ...                          ...    ...
# way     217416250              NaN                          NaN    NaN
#         219735025               43   Șoseaua București-Ploiești    NaN
#         318990256                6  Bulevardul Dimitrie Pompeiu    NaN
#         405520011              1-7     Bulevardul Ion Mihalache    NaN
#         948792755               22       Bulevardul Iuliu Maniu    NaN
#
#                                              website addr:country  \
# element id
# node    218092022                                NaN          NaN
#         271285333               https://www.ltib.ro/          NaN
#         444361321                                NaN          NaN
#         494791040                                NaN           RO
#         501932616                                NaN          NaN
# ...                                              ...          ...
# way     217416250                                NaN          NaN
#         219735025  https://www.bancatransilvania.ro/           RO
#         318990256                                NaN          NaN
#         405520011                                NaN          NaN
#         948792755                                NaN          NaN
#
#                   addr:postcode  ... currency:USDT currency:XBT  \
# element id                       ...
# node    218092022           NaN  ...           NaN          NaN
#         271285333           NaN  ...           NaN          NaN
#         444361321           NaN  ...           NaN          NaN
#         494791040        020882  ...           NaN          NaN
#         501932616           NaN  ...           NaN          NaN
# ...                         ...  ...           ...          ...
# way     217416250           NaN  ...           NaN          NaN
#         219735025        013685  ...           NaN          NaN
#         318990256        020337  ...           NaN          NaN
#         405520011        011171  ...           NaN          NaN
#         948792755        061107  ...           NaN          NaN
#
#                   payment:lightning payment:lightning_contactless  \
# element id
# node    218092022               NaN                           NaN
#         271285333               NaN                           NaN
#         444361321               NaN                           NaN
#         494791040               NaN                           NaN
#         501932616               NaN                           NaN
# ...                             ...                           ...
# way     217416250               NaN                           NaN
#         219735025               NaN                           NaN
#         318990256               NaN                           NaN
#         405520011               NaN                           NaN
#         948792755               NaN                           NaN
#
#                   payment:onchain note:en currency:BCH currency:SOL  \
# element id
# node    218092022             NaN     NaN          NaN          NaN
#         271285333             NaN     NaN          NaN          NaN
#         444361321             NaN     NaN          NaN          NaN
#         494791040             NaN     NaN          NaN          NaN
#         501932616             NaN     NaN          NaN          NaN
# ...                           ...     ...          ...          ...
# way     217416250             NaN     NaN          NaN          NaN
#         219735025             NaN     NaN          NaN          NaN
#         318990256             NaN     NaN          NaN          NaN
#         405520011             NaN     NaN          NaN          NaN
#         948792755             NaN     NaN          NaN          NaN
#
#                   currency:XRP currency:crypto
# element id
# node    218092022          NaN             NaN
#         271285333          NaN             NaN
#         444361321          NaN             NaN
#         494791040          NaN             NaN
#         501932616          NaN             NaN
# ...                        ...             ...
# way     217416250          NaN             NaN
#         219735025          NaN             NaN
#         318990256          NaN             NaN
#         405520011          NaN             NaN
#         948792755          NaN             NaN
#
# [12656 rows x 470 columns]

# %%
G_w = ox.graph_from_polygon(area, network_type="all")

# %%
street_nodes, street_edges = ox.graph_to_gdfs(G_w)

print(len(street_nodes), "intersections |", len(street_edges), "street segments")
# Out:
# 65285 intersections | 161274 street segments

# %%
fig, ax = plt.subplots(figsize=(10, 10))

street_edges.plot(ax=ax, color="#475569", linewidth=0.5)       
street_nodes.plot(ax=ax, color="#94a3b8", markersize=1)       
pois.plot(ax=ax, column="poi_category", markersize=6,           
          legend=True, cmap="tab10")

ax.set_axis_off()
ax.set_aspect("equal")
plt.title("Bucharest — streets + POIs")
fig.savefig("bucharest_map.svg", format="svg", bbox_inches="tight")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 5
#       1 fig, ax = plt.subplots(figsize=(10, 10))
#       2
#       3 street_edges.plot(ax=ax, color="#475569", linewidth=0.5)
#       4 street_nodes.plot(ax=ax, color="#94a3b8", markersize=1)
# ----> 5 pois.plot(ax=ax, column="poi_category", markersize=6,
#       6           legend=True, cmap="tab10")
#       7
#       8 ax.set_axis_off()
#
# File ~/Documents/Projects/City Maps/.venv/lib/python3.14/site-packages/geopandas/plotting.py:962, in GeoplotAccessor.__call__(self, *args, **kwargs)
#     960 kind = kwargs.pop("kind", "geo")
#     961 if kind == "geo":
# --> 962     return plot_dataframe(data, *args, **kwargs)
#     963 if kind in self._pandas_kinds:
#     964     # Access pandas plots
#     965     return PlotAccessor(data)(kind=kind, **kwargs)
#
# File ~/Documents/Projects/City Maps/.venv/lib/python3.14/site-packages/geopandas/plotting.py:831, in plot_dataframe(df, column, cmap, color, ax, cax, categorical, legend, scheme, k, vmin, vmax, markersize, figsize, legend_kwds, categories, classification_kwds, missing_kwds, aspect, autolim, **style_kwds)
#     829 subset = values[poly_idx & np.invert(nan_idx)]
#     830 if not polys.empty:
# --> 831     _plot_polygon_collection(
#     832         ax,
#     833         polys,
#     834         subset,
#     835         vmin=mn,
#     836         vmax=mx,
#     837         cmap=cmap,
#     838         autolim=autolim,
#     839         **style_kwds,
#     840     )
#     842 # plot all LineStrings and MultiLineString components in same collection
#     843 lines = expl_series[line_idx & np.invert(nan_idx)]
#
# File ~/Documents/Projects/City Maps/.venv/lib/python3.14/site-packages/geopandas/plotting.py:173, in _plot_polygon_collection(ax, geoms, values, color, cmap, vmin, vmax, autolim, **kwargs)
#     169     kwargs["color"] = color
#     171 _expand_kwargs(kwargs, multiindex)
# --> 173 collection = PatchCollection([_PolygonPatch(poly) for poly in geoms], **kwargs)
#     175 if values is not None:
#     176     collection.set_array(np.asarray(values))
#
# File ~/Documents/Projects/City Maps/.venv/lib/python3.14/site-packages/geopandas/plotting.py:107, in _PolygonPatch(polygon, **kwargs)
#     103 from matplotlib.patches import PathPatch
#     104 from matplotlib.path import Path
#     106 path = Path.make_compound_path(
# --> 107     Path(np.asarray(polygon.exterior.coords)[:, :2], closed=True),
#     108     *[
#     109         Path(np.asarray(ring.coords)[:, :2], closed=True)
#     110         for ring in polygon.interiors
#     111     ],
#     112 )
#     113 return PathPatch(path, **kwargs)
#
# File ~/Documents/Projects/City Maps/.venv/lib/python3.14/site-packages/shapely/geometry/base.py:224, in BaseGeometry.coords(self)
#     222 has_z = self.has_z
#     223 has_m = self.has_m if _geos_ge_312 else False
# --> 224 coords_array = shapely.get_coordinates(self, include_z=has_z, include_m=has_m)
#     225 return CoordinateSequence(coords_array)
#
# File ~/Documents/Projects/City Maps/.venv/lib/python3.14/site-packages/shapely/decorators.py:173, in deprecate_positional.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     171 @wraps(func)
#     172 def wrapper(*args, **kwargs):
# --> 173     result = func(*args, **kwargs)
#     175     n = len(args)
#     176     if n > warn_from:
#
# File ~/Documents/Projects/City Maps/.venv/lib/python3.14/site-packages/shapely/coordinates.py:268, in get_coordinates(geometry, include_z, return_index, include_m)
#     197 @deprecate_positional(["include_z", "return_index"], category=DeprecationWarning)
#     198 def get_coordinates(geometry, include_z=False, return_index=False, *, include_m=False):
#     199     """Get coordinates from a geometry array as an array of floats.
#     200
#     201     The shape of the returned array is (N, 2), with N being the number of
#    (...)    265
#     266     """
#     267     return lib.get_coordinates(
# --> 268         np.asarray(geometry, dtype=np.object_), include_z, include_m, return_index
#     269     )
#
# KeyboardInterrupt:

# %%
m = street_edges.explore(color="#475569", style_kwds={"weight": 1},
                         name="Streets", tiles="CartoDB positron")
pois.explore(m=m, column="poi_category", cmap="tab10",
             marker_kwds={"radius": 3},
             tooltip=["poi_category", "name"], name="POIs")
folium.LayerControl().add_to(m)

m

# %%
def make_hexgrid(boundary_gdf, res=9):
    aoi = boundary_gdf.to_crs(4326).union_all()          
    cells = h3.geo_to_cells(aoi, res)                    

    def cell_poly(c):
        return Polygon([(lng, lat) for lat, lng in h3.cell_to_boundary(c)])

    grid = gpd.GeoDataFrame({"h3_index": list(cells)},
                            geometry=[cell_poly(c) for c in cells], crs=4326)
    return grid

grid = make_hexgrid(g, res=9)     
print(len(grid), "cells")
print(grid)

grid.explore(tiles="CartoDB positron",
             style_kwds={"color": "#3b82f6", "weight": 0.5, "fillOpacity": 0.06})
